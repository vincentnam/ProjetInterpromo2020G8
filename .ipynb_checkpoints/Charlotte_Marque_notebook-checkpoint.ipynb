# %%
from pipeline import Pipeline, Process, Postprocess, Preprocess
import numpy as np
import pandas as pd

# %%
class MyPreProcess(Preprocess):
    process_desc = "Exemple de pre-process -> ne fait rien"
    def run(self, images):
        pass


class MyProcess(Process):
    process_desc = "Exemple de process -> ne fait rien"
    def run(self, images):
        pass
    
    
class MyPostProcess(Postprocess):
    process_desc = "Exemple de post-process -> ne fait rien"
    def run(self, images):
        pass

# %%
pipeline = Pipeline()
process_array = np.array([MyPreProcess()
                          ,MyProcess()
                          ,MyPostProcess()
                          ,MyPreProcess(verbose=0)])
pipeline.add_processes(process_array)
# Out:
# Preprocess :  Exemple de pre-process -> ne fait rien
# Process :  Exemple de process -> ne fait rien
# Postprocess :  Exemple de post-process -> ne fait rien
# Exemple de pre-process -> ne fait rien a été ajouté.
# Exemple de process -> ne fait rien a été ajouté.
# Exemple de post-process -> ne fait rien a été ajouté.
# Exemple de pre-process -> ne fait rien a été ajouté.

# %%
pipeline.print_process()
# Out:
# Exemple de pre-process -> ne fait rien
# Exemple de pre-process -> ne fait rien
# Exemple de process -> ne fait rien
# Exemple de post-process -> ne fait rien

# %%
import csv
path = "C:/Users/chach/OneDrive/Documents/SID/M2/"

# %%
fname = path + "Data_Interpromo/All Data/SEATGURU_INFO_AIRCRAFT.csv"
ifile = open(fname, "rt")
 
airline_name = []
aircraft_type = []
category = []
flight_type = []
count = []
total_seat = []
seat_class = []
seat_type = []
seat_position = []

try:
    reader = csv.reader(ifile, delimiter = ";")
    for row in reader:
        airline_name.append(row[1])
        aircraft_type.append(row[2])
        category.append(row[3])
        flight_type.append(row[4])
        count.append(row[5])
        total_seat.append(row[6])
        seat_class.append(row[7])
        seat_type.append(row[8])
        seat_position.append(row[9])
finally:
    ifile.close()

# %%
len(airline_name)
# Out:
# 10331

# %%
my_list = list(set(aircraft_type[2001:3000]))

# %%
my_list
# Out:
# ['Embraer 170 A',
#  'Boeing 777-200B 2',
#  'Airbus A330 300',
#  'Airlines Embraer 190',
#  'A320-200 C',
#  'Airbus A321-100',
#  'Airlines Airbus A320',
#  'Airbus A321 D',
#  'Airbus A330 33P',
#  'Boeing 777-200ER',
#  'Bombardier Q200 C',
#  'Airbus A320-200 C',
#  'Airbus A321-200 V1',
#  'Boeing 777-200',
#  'A321neo',
#  'Airbus A380 new',
#  'Airbus A320 V2',
#  'Boeing 747-400 B',
#  'ATR 72-500',
#  'Boeing 777-200 ER B',
#  '767-300ER',
#  'Bombardier Q200 A',
#  'Airbus A330-300 V2',
#  'A320',
#  'Airbus A321 C',
#  'Airbus A320-200 E',
#  'Airways Boeing 777-200 B',
#  'Boeing 787-8',
#  'Airbus A330 33E',
#  'A319-111',
#  'Boeing 777-200ER B',
#  'Airlines Airbus A320neo',
#  'Bombardier Q200 B',
#  'Boeing 777 300',
#  'Boeing 777-200 ER C',
#  'Airbus A320-200',
#  'Boeing 777-300ER D',
#  'Airlines Airbus A321',
#  'Embraer 190',
#  'Boeing 787-800 D',
#  'Boeing 787-9 V3',
#  'Embraer 170 B',
#  'Airbus A321-200',
#  'Airbus A319 E',
#  'A320-200 A',
#  'Airbus A319 D',
#  'Boeing 767-300',
#  '787-8',
#  'Embraer 190 A',
#  'Boeing 787-800 C',
#  'Boeing 787-9',
#  'Airbus A330-300',
#  'Airlines ATR 72-600',
#  'Boeing 787-9 V2',
#  'Boeing 777-200 3',
#  'A340-542',
#  'Airbus A350-900',
#  'Airbus A321',
#  '757-200 V1',
#  'Airbus A320',
#  'Boeing 747-400 C',
#  'Boeing 767-300ER B',
#  'Airbus A319-100',
#  'Airlines Boeing 777-200 V2',
#  'Airlines Boeing 767-300ER V3',
#  'Airways Boeing 777-300ER A',
#  'A320-200 B',
#  'Airlines Embraer195',
#  'Airbus A321 E',
#  'Boeing 777-300ER F',
#  'Airbus A330 200',
#  'Airbus A321-200 V2',
#  'Airbus A319',
#  'A330-200',
#  'Airbus A321-200 V3',
#  'Airways A330 E new',
#  'Airbus A319 V2',
#  'Airbus A320-200 D',
#  'Bombardier Q400',
#  'Airbus A319 C',
#  'Airlines Embraer 195',
#  'Boeing 777-300ER E',
#  'Airbus A318',
#  'Airbus A318-100',
#  'Boeing 777-200ER A',
#  'Boeing 787-800 B',
#  'Boeing 747-400 D',
#  'Airlines Airbus A319',
#  'Boeing 787-900',
#  'Airbus A330-200',
#  'Boeing 777-200 ER D',
#  'Embraer 190 B',
#  'Boeing 747-400 full',
#  'Airlines Airbus A330-200',
#  'Airlines Q400',
#  'Airbus A380',
#  'Airbus A350-1000']

# %%
fname = path + "Data_Interpromo/All Data/Correspondances_images.csv"
file = open(fname, 'wt', newline='')
 

try:
    writer = csv.writer(file, delimiter = ";")
    #écriture de l'entête
    writer.writerow(('Airline_Name', 'Aircraft_Type', 'Images'))
    
    for j in my_list:
        index = []
        for i in range(2001,3000):
            if j == aircraft_type[i] :
                index.append(i)
        #print(index)
        a = (str(min(index)+1) + "-" + str(max(index)+1))
        #print(a)
        writer.writerow((j, index))
        #print(j, min(index), max(index))

finally:
    file.close()

# %%
for j in my_list:
    #print(j)
    index = []
    for i in range(1,len(aircraft_type)):
        if j == aircraft_type[i] :
            index.append(i)
    #print(index)
    #a = min(index) + "-" + max(index)
    print(j, str(min(index)) + '-' + str(max(index)))
# Out:
# Dash 83 508-1891
# Boeing 747-8I 6158-6171
# Airlines Boeing 737-900 F 9497-9508
# Airbus A330-243 4081-4090
# Airlines Embraer195 2367-2371
# Airlines Airbus A330 200 new 3687-3698
# Boeing 747-400 C 2737-6131
# Q400A 4347-4350
# 737-600 9166-9170
# Canadair CRJ900 1846-5312
# g 777-200 ER new 8246-8254
# Airlines Boeing 787-8 7726-7737
# Airbus A330 33E 2937-2947
# Boeing 737-900 5809-6966
# Boeing 747-400 combi B 5917-5936
# Airbus A319 B 4897-4904
# Airbus A321neo 1417-5081
# Boeing 777 300ER 3265-3276
# Airlines Embraer 190 2580-8725
# Airlines Boeing 777-200 V2 2356-2366
# Airlines Embraer ERJ-170 3939-3946
# Airways Boeing 777-300ER new 4418-4431
# A320-200 A 2506-7564
# SB Airbus A320-200 304-311
